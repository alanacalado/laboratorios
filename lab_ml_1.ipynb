# %%
! pip install pandas
# Out:
# ...
#   Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.5 MB 10.1 MB/s eta 0:00:01
#    ------------ --------------------------- 3.7/11.5 MB 9.9 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.5 MB 10.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.1/11.5 MB 10.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 9.1 MB/s eta 0:00:00
# Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl (12.6 MB)
# ...

# %%
import pandas as pd

# %% [markdown]
# # MACHINE LEARNING : RECONHECENDO ANIMAIS

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
! pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.2 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 10.3 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import pandas as pd
from IPython.display import display, HTML

# %%
img = 'https://animalequality.org.br/app/uploads/2021/01/shutterstock_1103310314-1024x0-c-default.jpg'

# %%
data = {'Imagem':['<img src="https://encurtador.com.br/SKSmC" width="100"/>','<img src="https://encurtador.com.br/E1JrZ" width="100"/>','<img src="https://encurtador.com.br/mVfCt" width="100"/>','<img src="https://encurtador.com.br/IuMKh" width="100"/>','<img src="https://encurtador.com.br/WnERH" width="100"/>','<img src="https://abre.ai/lalr" width="100"/>','<img src="https://abre.ai/lalv" width="100"/>'],
        'galinha_papagaio': [1, 1,1, 1, 1, 1, 1],
        'tem_bico': ['Sim','Sim','Sim','Sim','Sim' ,'Sim' ,'Sim' ],
        'risco_de_extinção': ['Não', 'Sim','Não', 'Sim' ,'Não' ,'Sim' , 'Não'],
        'faz_cocorico': ['Sim', 'Não', 'Sim', 'Não' , 'Sim' , 'Não' , 'Sim']
        }
df = pd.DataFrame(data)

# Exiba a tabela
display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Imagem</th>
#       <th>galinha_papagaio</th>
#       <th>tem_bico</th>
#       <th>risco_de_extinção</th>
#       <th>faz_cocorico</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://encurtador.com.br/SKSmC" width="100"/></td>
#       <td>1</td>
#       <td>Sim</td>
#       <td>Não</td>
#       <td>Sim</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://encurtador.com.br/E1JrZ" width="100"/></td>
#       <td>1</td>
#       <td>Sim</td>
#       <td>Sim</td>
#       <td>Não</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://encurtador.com.br/mVfCt" width="100"/></td>
#       <td>1</td>
#       <td>Sim</td>
#       <td>Não</td>
#       <td>Sim</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://encurtador.com.br/IuMKh" width="100"/></td>
# ...

# %%
# 1 = SIM , 0 = NÃO
# Tem bico ?
# Tem risco de extinção ?
# Faz cocoricó ?

# PAPAGAIO

papagaio1 = [1,1,1]
papagaio2 = [1,1,0]
papagaio3 = [0,1,1]

# GALINHA

galinha1 = [1,0,1]
galinha2 = [1,1,1]
galinha3 = [0,1,0]
galinha4 = [0,0,1]

# %%
dados = [papagaio1,papagaio2,papagaio3,galinha1,galinha2,galinha3,galinha4]
classes = [1 , 1 , 1 , 0 , 0 , 0, 0]

# %%
dados
# Out:
# [[1, 1, 1], [1, 1, 0], [0, 1, 1], [1, 0, 1], [1, 1, 1], [0, 1, 0], [0, 0, 1]]

# %%
! pip install scikit-learn

# %%
from sklearn.svm import LinearSVC

# %%
modelo = LinearSVC()

# %%
modelo.fit(dados , classes)
# Out:
# LinearSVC()

# %%
animal_misterioso = [ 0,1,0]
previsao = modelo.predict([animal_misterioso])

# %%
previsao
# Out:
# array([1])

# %%
animal_misterioso2 = [ 1,0,1]
previsao2 = modelo.predict([animal_misterioso2])

# %%
previsao2
# Out:
# array([0])

# %%
treinox = [papagaio1,papagaio2,papagaio3,galinha1,galinha2,galinha3,galinha4]
treinoy = [1 , 1 , 1 , 0 , 0 , 0, 0]

# %%
misterio1 = [ 0,1,0]
misterio2 = [ 1,0,0]
misterio3 = [ 1,0,1]

# %%
testex = [misterio1,misterio2,misterio3]
previsoes = modelo.predict(testex)

# %%
testey = [1,0,1]

# %%
from sklearn.metrics import accuracy_score

# %%
taxa_acerto = accuracy_score(testey,previsoes) *100

print(f'Acurácia:{taxa_acerto:2f}%')
# Out:
# Acurácia:66.666667%
